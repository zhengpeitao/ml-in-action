# %% [markdown]
# prophet
#
# https://facebook.github.io/prophet/

# %%
# Python
import pandas as pd
from prophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
# 数据
df = pd.read_csv('example_wp_log_peyton_manning.csv')
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
# 训练
m = Prophet()
m.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# 预测 365天的任务
future = m.make_future_dataframe(periods=730)
future.tail()
# Out:
#              ds
# 3630 2018-01-15
# 3631 2018-01-16
# 3632 2018-01-17
# 3633 2018-01-18
# 3634 2018-01-19

# %%
# 预测结果
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3630 2018-01-15  8.115597    6.861470    9.359037
# 3631 2018-01-16  7.904136    6.673452    9.161648
# 3632 2018-01-17  7.738104    6.468889    9.026894
# 3633 2018-01-18  7.751675    6.495780    9.004009
# 3634 2018-01-19  7.772210    6.445154    9.036171

# %%
# 可视化
fig1 = m.plot(forecast)

# %%
# 时间序列的趋势、年度季节性和每周季节性
fig2 = m.plot_components(forecast)
